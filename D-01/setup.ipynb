# %% [markdown]
# # 🚀 Day 01 - Setup & Environment Check
#
# This notebook verifies that your Python environment is properly configured for the 30-day learning program.

# %%
# Check Python version
import sys
print(f"Python Version: {sys.version}")
print(f"Python Path: {sys.executable}")

# %%
# Check if Jupyter is working
print("✅ Jupyter Notebook is working!")
print("You are all set for your 30-day Python learning journey!")

# %%
# List installed packages
# !pip list

# %% [markdown]
# ---
# ## ✅ Environment is ready!
# You can now start your 30-day Python learning program. Create new day folders as you progress.
